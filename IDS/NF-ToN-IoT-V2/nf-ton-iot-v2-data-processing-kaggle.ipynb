# %% [markdown]
# # Intrusion Detection System using the NF-ToN-IoT-V2 Dataset

# %% [markdown]
# # Featuring with pandas

# %%
import dask.dataframe as dd
import pandas as pd

# %% [markdown]
# # Reading
#
# If you have less than 16GB of Ram use dask instead

# %%
# pandas
df = pd.read_csv('/kaggle/input/nf-ton-iot-v2/9bafce9d380588c2_MOHANAD_A4706/data/NF-ToN-IoT-v2.csv')  # records: 16_940_496
df.head()

# Dask:
#ddf = dd.read_csv('/kaggle/input/nf-ton-iot-v2/9bafce9d380588c2_MOHANAD_A4706/data/NF-ToN-IoT-v2.csv')  # records: 16_940_496
#ddf.head()
# Out:
#    IPV4_SRC_ADDR  L4_SRC_PORT    IPV4_DST_ADDR  L4_DST_PORT  PROTOCOL  \
# 0  192.168.1.193        49235     192.168.1.33         4444         6
# 1  192.168.1.193        49228    192.168.1.152         1880         6
# 2  192.168.1.152            0    192.168.1.193            0         1
# 3  192.168.1.169        65317  239.255.255.250         1900        17
# 4   192.168.1.79        60766    192.168.1.255        15600        17
#
#    L7_PROTO  IN_BYTES  IN_PKTS  OUT_BYTES  OUT_PKTS  ...  TCP_WIN_MAX_IN  \
# 0       0.0    155392      202      34552       149  ...           45555
# 1       0.0      1600       40      35741        65  ...           16425
# 2       0.0       212        2          0         0  ...               0
# 3       0.0       165        1          0         0  ...               0
# 4       0.0        63        1          0         0  ...               0
#
#    TCP_WIN_MAX_OUT  ICMP_TYPE  ICMP_IPV4_TYPE  DNS_QUERY_ID  DNS_QUERY_TYPE  \
# ...

# %%
df.shape
# Out:
# (16940496, 45)

# %% [markdown]
# ### Knowing the dataset
#
# - All values are numeric
# - No missing values
# - No duplicates

# %%
df.isnull().sum()
# Out:
# IPV4_SRC_ADDR                  0
# L4_SRC_PORT                    0
# IPV4_DST_ADDR                  0
# L4_DST_PORT                    0
# PROTOCOL                       0
# L7_PROTO                       0
# IN_BYTES                       0
# IN_PKTS                        0
# OUT_BYTES                      0
# OUT_PKTS                       0
# TCP_FLAGS                      0
# CLIENT_TCP_FLAGS               0
# SERVER_TCP_FLAGS               0
# FLOW_DURATION_MILLISECONDS     0
# DURATION_IN                    0
# DURATION_OUT                   0
# MIN_TTL                        0
# MAX_TTL                        0
# LONGEST_FLOW_PKT               0
# SHORTEST_FLOW_PKT              0
# MIN_IP_PKT_LEN                 0
# MAX_IP_PKT_LEN                 0
# SRC_TO_DST_SECOND_BYTES        0
# DST_TO_SRC_SECOND_BYTES        0
# RETRANSMITTED_IN_BYTES         0
# RETRANSMITTED_IN_PKTS          0
# RETRANSMITTED_OUT_BYTES        0
# RETRANSMITTED_OUT_PKTS         0
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Removing Columns
#
# Removing desiring columns and choosing a random sample of the original dataset

# %%
df = df.drop(columns=['IPV4_SRC_ADDR', 'IPV4_DST_ADDR'])
df = df.sample(n=2_500_00, random_state=69)

# %%
df.shape
# Out:
# (250000, 43)

# %% [markdown]
# # Saving the dataset
#
# Saving the new dataset into parquet format to be more efficient

# %%
df.to_parquet('./NF-ToN-IoT-V2_FNIDS_last.parquet', compression='gzip')
